# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjh7669/DL/blob/main/ocw_CV/08_VOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade gdown
# Out:
# Requirement already up-to-date: gdown in /usr/local/lib/python3.7/dist-packages (3.13.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.0.12)
# Requirement already satisfied, skipping upgrade: requests[socks]>=2.12.0 in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.41.1)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown) (2021.5.30)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown) (2.10)
# Requirement already satisfied, skipping upgrade: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.12.0->gdown) (1.7.1)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import gdown
md5 = '785f4c1001e93c544c029df70332fc34'
url = 'https://drive.google.com/file/d/14eyB2lkxrG83fGy4t395sgZqADOYJ_yE/view?usp=sharing'
output = '/mydrive/VOCtrainval_11-May-2012.tar'
gdown.cached_download(url, output, md5=md5)
# Out:
# Computing MD5: /mydrive/VOCtrainval_11-May-2012.tar
# MD5 matches: /mydrive/VOCtrainval_11-May-2012.tar
# '/mydrive/VOCtrainval_11-May-2012.tar'

# %%
# %cd ..
# Out:
# /content

# %%
# !git clone https://github.com/shevious/keras-yolo4.git
# Out:
# Cloning into 'keras-yolo4'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 92 (delta 6), reused 7 (delta 2), pack-reused 72
# Unpacking objects: 100% (92/92), done.

# %%
# !ls
# Out:
# 2007_test.txt	    convert.py	      raccoon_anno.py	   train_raccoon.py
# 2007_train.txt	    decode_np.py      raccoon_test.txt	   voc_annotation.py
# 2007_val.txt	    font	      raccoon_train.txt    yolo4
# 2012_train.txt	    kmeans.py	      README.md		   yolo4.png
# 2012_val.txt	    LICENSE	      test.py		   yolo4.py
# callback_eval.py    model_data	      train_bottleneck.py  yolov4.cfg
# coco_annotation.py  predict_video.py  train.py

# %%
# !cd keras-yolo4
# Out:
# /bin/bash: line 0: cd: keras-yolo4: No such file or directory

# %%
# !tar xf /mydrive/VOCtrainval_11-May-2012.tar

# %%
# !ls data/VOC2012/Annotations | head -5
# Out:
# ls: cannot access 'data/VOC2012/Annotations': No such file or directory

# %%
# !ls
# Out:
# 2007_test.txt	    convert.py	      raccoon_anno.py	   train_raccoon.py
# 2007_train.txt	    decode_np.py      raccoon_test.txt	   voc_annotation.py
# 2007_val.txt	    font	      raccoon_train.txt    VOCdevkit
# 2012_train.txt	    kmeans.py	      README.md		   yolo4
# 2012_val.txt	    LICENSE	      test.py		   yolo4.png
# callback_eval.py    model_data	      train_bottleneck.py  yolo4.py
# coco_annotation.py  predict_video.py  train.py		   yolov4.cfg

# %%
# !ln -s VOCdevkit data

# %%
# !ls data/VOC2012/Annotations | head -5
# Out:
# 2007_000027.xml
# 2007_000032.xml
# 2007_000033.xml
# 2007_000039.xml
# 2007_000042.xml

# %%
# !cat data/VOC2012/Annotations/2007_000027.xml
# Out:
# <annotation>
# 	<folder>VOC2012</folder>
# 	<filename>2007_000027.jpg</filename>
# 	<source>
# 		<database>The VOC2007 Database</database>
# 		<annotation>PASCAL VOC2007</annotation>
# 		flickr
# 	</source>
# 	<size>
# 		<width>486</width>
# 		<height>500</height>
# 		<depth>3</depth>
# 	</size>
# 	<segmented>0</segmented>
# 	<object>
# 		<name>person</name>
# 		<pose>Unspecified</pose>
# 		<truncated>0</truncated>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>174</xmin>
# 			<ymin>101</ymin>
# 			<xmax>349</xmax>
# 			<ymax>351</ymax>
# 		</bndbox>
# 		<part>
# 			<name>head</name>
# 			<bndbox>
# 				<xmin>169</xmin>
# 				<ymin>104</ymin>
# 				<xmax>209</xmax>
# 				<ymax>146</ymax>
# 			</bndbox>
# 		</part>
# 		<part>
# 			<name>hand</name>
# 			<bndbox>
# 				<xmin>278</xmin>
# 				<ymin>210</ymin>
# 				<xmax>297</xmax>
# 				<ymax>233</ymax>
# 			</bndbox>
# 		</part>
# 		<part>
# 			<name>foot</name>
# 			<bndbox>
# 				<xmin>273</xmin>
# 				<ymin>333</ymin>
# 				<xmax>297</xmax>
# 				<ymax>354</ymax>
# 			</bndbox>
# 		</part>
# 		<part>
# 			<name>foot</name>
# 			<bndbox>
# 				<xmin>319</xmin>
# 				<ymin>307</ymin>
# 				<xmax>340</xmax>
# 				<ymax>326</ymax>
# 			</bndbox>
# 		</part>
# 	</object>
# </annotation>

# %%
import xml.etree.ElementTree as ET
from os import getcwd

sets = [('2012', 'train'), ('2012', 'val')]
classes = ["aeroplane", "bicycle", "bird", "boat", "bottle", "bus", "car", "cat", "chair", "cow", "diningtable", "dog", "horse", "motorbike", "person", "pottedplant", "sheep", "sofa", "train", "tvmonitor"]

def convert_annotation(year, image_id, list_file):
  in_file = open('data/VOC%s/Annotations/%s.xml' %(year, image_id))
  tree = ET.parse(in_file)
  root = tree.getroot()

  for obj in root.iter('object'):
    difficult = obj.find('difficult').text
    cls = obj.find('name').text
    if cls not in classes or int(difficult)==1:
      continue
    cls_id = classes.index(cls)
    xmlbox = obj.find('bndbox')
    b = (int(xmlbox.find('xmin').text), int(xmlbox.find('ymin').text), int(xmlbox.find('xmax').text), int(xmlbox.find('ymax').text))
    list_file.write(" " + ",".join([str(a) for a in b]) + ',' + str(cls_id))

wd = getcwd()

for year, image_set in sets:
  image_ids = open('data/VOC%s/ImageSets/Main/%s.txt' %(year, image_set)).read().strip().split()
  list_file = open('%s_%s.txt' %(year, image_set), 'w')
  for image_id in image_ids:
    list_file.write('%s/data/VOC%s/JPEGImages/%s.jpg'%(wd, year,image_id))
    convert_annotation(year, image_id, list_file)
    list_file.write('\n')
  list_file.close()

# %%
# !head -5 2012_train.txt
# !head -5 2012_val.txt
# Out:
# /content/keras-yolo4/data/VOC2012/JPEGImages/2008_000008.jpg 53,87,471,420,12 158,44,289,167,14
# /content/keras-yolo4/data/VOC2012/JPEGImages/2008_000015.jpg 270,1,378,176,4 57,1,164,150,4
# /content/keras-yolo4/data/VOC2012/JPEGImages/2008_000019.jpg 139,2,372,197,11 165,66,318,236,11 361,1,480,112,11
# /content/keras-yolo4/data/VOC2012/JPEGImages/2008_000023.jpg 6,1,314,262,19 40,97,121,411,4 137,36,169,109,14 180,36,216,104,14 96,39,123,103,14
# /content/keras-yolo4/data/VOC2012/JPEGImages/2008_000028.jpg 158,199,231,240,6 47,202,94,238,6
# /content/keras-yolo4/data/VOC2012/JPEGImages/2008_000002.jpg 34,11,448,293,19
# /content/keras-yolo4/data/VOC2012/JPEGImages/2008_000003.jpg 46,11,500,333,18 62,190,83,243,14
# /content/keras-yolo4/data/VOC2012/JPEGImages/2008_000007.jpg 1,230,428,293,3
# /content/keras-yolo4/data/VOC2012/JPEGImages/2008_000009.jpg 217,161,294,221,9 465,167,500,218,9
# /content/keras-yolo4/data/VOC2012/JPEGImages/2008_000016.jpg 91,15,392,353,19

# %% [markdown]
# # COCO dataset

# %%
import gdown
md5 = '00a4878d05f4d832ab38861b32061283'
url = 'https://drive.google.com/uc?id=1cewMfusmPjYWbrnuJRuKhPMwRe_b9PaT'
output = 'yolov4.weights'
#gdown.download(url, output, quiet=False)
gdown.cached_download(url, output, md5=md5)
# Out:
# Cached Downloading: yolov4.weights
# Downloading...
# From: https://drive.google.com/uc?id=1cewMfusmPjYWbrnuJRuKhPMwRe_b9PaT
# To: /root/.cache/gdown/tmpv1jb4br0/dl
# 258MB [00:02, 114MB/s]
# Computing MD5: yolov4.weights
# MD5 matches: yolov4.weights
# 'yolov4.weights'

# %%
import os
import colorsys

import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input

from yolo4.model import yolo_eval, yolo4_body
from yolo4.utils import letterbox_image

from PIL import Image, ImageFont, ImageDraw
from timeit import default_timer as timer
import matplotlib.pyplot as plt

from operator import itemgetter

import tensorflow as tf

class Yolo4(object):
    def get_class(self):
        classes_path = os.path.expanduser(self.classes_path)
        with open(classes_path) as f:
            class_names = f.readlines()
        class_names = [c.strip() for c in class_names]
        return class_names

    def get_anchors(self):
        anchors_path = os.path.expanduser(self.anchors_path)
        with open(anchors_path) as f:
            anchors = f.readline()
        anchors = [float(x) for x in anchors.split(',')]
        return np.array(anchors).reshape(-1, 2)

    def load_yolo(self):
        model_path = os.path.expanduser(self.model_path)
        assert model_path.endswith('.h5'), 'Keras model or weights must be a .h5 file.'

        self.class_names = self.get_class()
        self.anchors = self.get_anchors()

        num_anchors = len(self.anchors)
        num_classes = len(self.class_names)

        # Generate colors for drawing bounding boxes.
        hsv_tuples = [(x / len(self.class_names), 1., 1.)
                      for x in range(len(self.class_names))]
        self.colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
        self.colors = list(
            map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)),
                self.colors))

        #self.sess = K.get_session()

        # Load model, or construct model and load weights.
        self.yolo4_model = yolo4_body(Input(shape=(608, 608, 3)), num_anchors//3, num_classes)
        #print(self.yolo4_model.summary())
        #print('num_anchors =', num_anchors)
        #print('num_classes =', num_classes)

        # Read and convert darknet weight
        print('Loading weights.')
        weights_file = open(self.weights_path, 'rb')
        major, minor, revision = np.ndarray(
            shape=(3, ), dtype='int32', buffer=weights_file.read(12))
        if (major*10+minor)>=2 and major<1000 and minor<1000:
            seen = np.ndarray(shape=(1,), dtype='int64', buffer=weights_file.read(8))
        else:
            seen = np.ndarray(shape=(1,), dtype='int32', buffer=weights_file.read(4))
        print('Weights Header: ', major, minor, revision, seen)

        convs_to_load = []
        bns_to_load = []
        for i in range(len(self.yolo4_model.layers)):
            layer_name = self.yolo4_model.layers[i].name
            if layer_name == 'conv2d':
                convs_to_load.append((0, i))
            elif layer_name.startswith('conv2d_'):
                convs_to_load.append((int(layer_name[7:]), i))
            if layer_name == 'batch_normalization':
                bns_to_load.append((0, i))
            elif layer_name.startswith('batch_normalization_'):
                bns_to_load.append((int(layer_name[20:]), i))

        convs_sorted = sorted(convs_to_load, key=itemgetter(0))
        bns_sorted = sorted(bns_to_load, key=itemgetter(0))
        #print('bns_sorted = ', bns_sorted)

        bn_index = 0
        for i in range(len(convs_sorted)):
            print('Converting ', i)
            if i == 93 or i == 101 or i == 109:
                #no bn, with bias
                weights_shape = self.yolo4_model.layers[convs_sorted[i][1]].get_weights()[0].shape
                bias_shape = self.yolo4_model.layers[convs_sorted[i][1]].get_weights()[0].shape[3]
                filters = bias_shape
                size = weights_shape[0]
                darknet_w_shape = (filters, weights_shape[2], size, size)
                weights_size = np.product(weights_shape)

                conv_bias = np.ndarray(
                    shape=(filters, ),
                    dtype='float32',
                    buffer=weights_file.read(filters * 4))
                conv_weights = np.ndarray(
                    shape=darknet_w_shape,
                    dtype='float32',
                    buffer=weights_file.read(weights_size * 4))
                conv_weights = np.transpose(conv_weights, [2, 3, 1, 0])
                self.yolo4_model.layers[convs_sorted[i][1]].set_weights([conv_weights, conv_bias])
            else:
                #with bn, no bias
                weights_shape = self.yolo4_model.layers[convs_sorted[i][1]].get_weights()[0].shape
                size = weights_shape[0]
                bn_shape = self.yolo4_model.layers[bns_sorted[bn_index][1]].get_weights()[0].shape
                filters = bn_shape[0]
                '''
                print('##')
                print('i = ', i)
                print('bn_index = ', bn_index)
                print('convs_sorted[i][1] = ', convs_sorted[i][1])
                print('bns_sorted[bn_index][1] = ', bns_sorted[bn_index][1])
                print('bn_shape = ', bn_shape)
                print('w layer name = ', self.yolo4_model.layers[convs_sorted[i][1]].name)
                print('bn layer name = ', self.yolo4_model.layers[bns_sorted[bn_index][1]].name)
                '''
                darknet_w_shape = (filters, weights_shape[2], size, size)
                weights_size = np.product(weights_shape)

                conv_bias = np.ndarray(
                    shape=(filters, ),
                    dtype='float32',
                    buffer=weights_file.read(filters * 4))
                bn_weights = np.ndarray(
                    shape=(3, filters),
                    dtype='float32',
                    buffer=weights_file.read(filters * 12))

                bn_weight_list = [
                    bn_weights[0],  # scale gamma
                    conv_bias,  # shift beta
                    bn_weights[1],  # running mean
                    bn_weights[2]  # running var
                ]
                self.yolo4_model.layers[bns_sorted[bn_index][1]].set_weights(bn_weight_list)

                conv_weights = np.ndarray(
                    shape=darknet_w_shape,
                    dtype='float32',
                    buffer=weights_file.read(weights_size * 4))
                conv_weights = np.transpose(conv_weights, [2, 3, 1, 0])
                self.yolo4_model.layers[convs_sorted[i][1]].set_weights([conv_weights])

                bn_index += 1

        weights_file.close()

        self.yolo4_model.save(self.model_path)
        for i in range(len(self.yolo4_model.layers)):
            lens = len(self.yolo4_model.layers[i].get_weights())
            for j in range(lens):
              shape = self.yolo4_model.layers[i].get_weights()[j].shape
              print('i = ', i, 'shape = ', shape)


        if self.gpu_num>=2:
            self.yolo4_model = multi_gpu_model(self.yolo4_model, gpus=self.gpu_num)

        self.input_image_shape = K.placeholder(shape=(2, ))
        self.boxes, self.scores, self.classes = yolo_eval(self.yolo4_model.output, self.anchors,
                len(self.class_names), self.input_image_shape,
                score_threshold=self.score)

    def __init__(self, score, iou, anchors_path, classes_path, model_path, weights_path, gpu_num=1):
        self.score = score
        self.iou = iou
        self.anchors_path = anchors_path
        self.classes_path = classes_path
        self.weights_path = weights_path
        self.model_path = model_path
        self.gpu_num = gpu_num
        self.load_yolo()

    def close_session(self):
        self.sess.close()

if __name__ == '__main__':
    model_path = 'yolo4_weight.h5'
    anchors_path = 'model_data/yolo4_anchors.txt'
    classes_path = 'model_data/coco_classes.txt'
    weights_path = 'yolov4.weights'

    score = 0.5
    iou = 0.5

    model_image_size = (608, 608)

    yolo4_model = Yolo4(score, iou, anchors_path, classes_path, model_path, weights_path)

    #yolo4_model.close_session()
# Out:
# Loading weights.
# Weights Header:  0 2 5 [32032000]
# Converting  0
# Converting  1
# Converting  2
# Converting  3
# Converting  4
# Converting  5
# Converting  6
# Converting  7
# Converting  8
# Converting  9
# Converting  10
# Converting  11
# Converting  12
# Converting  13
# Converting  14
# Converting  15
# Converting  16
# Converting  17
# Converting  18
# Converting  19
# Converting  20
# Converting  21
# Converting  22
# Converting  23
# Converting  24
# Converting  25
# Converting  26
# Converting  27
# Converting  28
# Converting  29
# Converting  30
# Converting  31
# Converting  32
# Converting  33
# Converting  34
# Converting  35
# Converting  36
# Converting  37
# Converting  38
# Converting  39
# Converting  40
# Converting  41
# Converting  42
# Converting  43
# Converting  44
# Converting  45
# Converting  46
# Converting  47
# Converting  48
# Converting  49
# Converting  50
# Converting  51
# Converting  52
# Converting  53
# Converting  54
# Converting  55
# Converting  56
# Converting  57
# Converting  58
# Converting  59
# Converting  60
# Converting  61
# Converting  62
# Converting  63
# Converting  64
# Converting  65
# Converting  66
# Converting  67
# Converting  68
# Converting  69
# Converting  70
# Converting  71
# Converting  72
# Converting  73
# Converting  74
# Converting  75
# Converting  76
# Converting  77
# Converting  78
# Converting  79
# Converting  80
# Converting  81
# Converting  82
# Converting  83
# Converting  84
# Converting  85
# Converting  86
# Converting  87
# Converting  88
# Converting  89
# Converting  90
# Converting  91
# Converting  92
# Converting  93
# Converting  94
# Converting  95
# Converting  96
# Converting  97
# Converting  98
# Converting  99
# Converting  100
# Converting  101
# Converting  102
# Converting  103
# Converting  104
# Converting  105
# Converting  106
# Converting  107
# Converting  108
# Converting  109
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# i =  1 shape =  (3, 3, 3, 32)
# i =  2 shape =  (32,)
# i =  2 shape =  (32,)
# i =  2 shape =  (32,)
# i =  2 shape =  (32,)
# i =  5 shape =  (3, 3, 32, 64)
# i =  6 shape =  (64,)
# i =  6 shape =  (64,)
# i =  6 shape =  (64,)
# i =  6 shape =  (64,)
# i =  8 shape =  (1, 1, 64, 64)
# i =  9 shape =  (64,)
# i =  9 shape =  (64,)
# i =  9 shape =  (64,)
# i =  9 shape =  (64,)
# i =  11 shape =  (1, 1, 64, 32)
# i =  12 shape =  (32,)
# i =  12 shape =  (32,)
# i =  12 shape =  (32,)
# i =  12 shape =  (32,)
# i =  14 shape =  (3, 3, 32, 64)
# i =  15 shape =  (64,)
# i =  15 shape =  (64,)
# i =  15 shape =  (64,)
# i =  15 shape =  (64,)
# i =  18 shape =  (1, 1, 64, 64)
# i =  19 shape =  (1, 1, 64, 64)
# i =  20 shape =  (64,)
# i =  20 shape =  (64,)
# i =  20 shape =  (64,)
# i =  20 shape =  (64,)
# i =  21 shape =  (64,)
# i =  21 shape =  (64,)
# i =  21 shape =  (64,)
# i =  21 shape =  (64,)
# i =  25 shape =  (1, 1, 128, 64)
# i =  26 shape =  (64,)
# i =  26 shape =  (64,)
# i =  26 shape =  (64,)
# i =  26 shape =  (64,)
# i =  29 shape =  (3, 3, 64, 128)
# i =  30 shape =  (128,)
# i =  30 shape =  (128,)
# i =  30 shape =  (128,)
# i =  30 shape =  (128,)
# i =  32 shape =  (1, 1, 128, 64)
# i =  33 shape =  (64,)
# i =  33 shape =  (64,)
# i =  33 shape =  (64,)
# i =  33 shape =  (64,)
# i =  35 shape =  (1, 1, 64, 64)
# i =  36 shape =  (64,)
# i =  36 shape =  (64,)
# i =  36 shape =  (64,)
# i =  36 shape =  (64,)
# i =  38 shape =  (3, 3, 64, 64)
# i =  39 shape =  (64,)
# i =  39 shape =  (64,)
# i =  39 shape =  (64,)
# i =  39 shape =  (64,)
# i =  42 shape =  (1, 1, 64, 64)
# i =  43 shape =  (64,)
# i =  43 shape =  (64,)
# i =  43 shape =  (64,)
# i =  43 shape =  (64,)
# i =  45 shape =  (3, 3, 64, 64)
# i =  46 shape =  (64,)
# i =  46 shape =  (64,)
# i =  46 shape =  (64,)
# i =  46 shape =  (64,)
# i =  49 shape =  (1, 1, 64, 64)
# i =  50 shape =  (1, 1, 128, 64)
# i =  51 shape =  (64,)
# i =  51 shape =  (64,)
# i =  51 shape =  (64,)
# i =  51 shape =  (64,)
# i =  52 shape =  (64,)
# i =  52 shape =  (64,)
# i =  52 shape =  (64,)
# i =  52 shape =  (64,)
# i =  56 shape =  (1, 1, 128, 128)
# i =  57 shape =  (128,)
# i =  57 shape =  (128,)
# i =  57 shape =  (128,)
# i =  57 shape =  (128,)
# i =  60 shape =  (3, 3, 128, 256)
# i =  61 shape =  (256,)
# i =  61 shape =  (256,)
# i =  61 shape =  (256,)
# i =  61 shape =  (256,)
# i =  63 shape =  (1, 1, 256, 128)
# i =  64 shape =  (128,)
# i =  64 shape =  (128,)
# i =  64 shape =  (128,)
# i =  64 shape =  (128,)
# i =  66 shape =  (1, 1, 128, 128)
# i =  67 shape =  (128,)
# i =  67 shape =  (128,)
# i =  67 shape =  (128,)
# i =  67 shape =  (128,)
# i =  69 shape =  (3, 3, 128, 128)
# i =  70 shape =  (128,)
# i =  70 shape =  (128,)
# i =  70 shape =  (128,)
# i =  70 shape =  (128,)
# i =  73 shape =  (1, 1, 128, 128)
# i =  74 shape =  (128,)
# i =  74 shape =  (128,)
# i =  74 shape =  (128,)
# i =  74 shape =  (128,)
# i =  76 shape =  (3, 3, 128, 128)
# i =  77 shape =  (128,)
# i =  77 shape =  (128,)
# i =  77 shape =  (128,)
# i =  77 shape =  (128,)
# i =  80 shape =  (1, 1, 128, 128)
# i =  81 shape =  (128,)
# i =  81 shape =  (128,)
# i =  81 shape =  (128,)
# i =  81 shape =  (128,)
# i =  83 shape =  (3, 3, 128, 128)
# i =  84 shape =  (128,)
# i =  84 shape =  (128,)
# i =  84 shape =  (128,)
# i =  84 shape =  (128,)
# i =  87 shape =  (1, 1, 128, 128)
# i =  88 shape =  (128,)
# i =  88 shape =  (128,)
# i =  88 shape =  (128,)
# i =  88 shape =  (128,)
# i =  90 shape =  (3, 3, 128, 128)
# i =  91 shape =  (128,)
# i =  91 shape =  (128,)
# i =  91 shape =  (128,)
# i =  91 shape =  (128,)
# i =  94 shape =  (1, 1, 128, 128)
# i =  95 shape =  (128,)
# i =  95 shape =  (128,)
# i =  95 shape =  (128,)
# i =  95 shape =  (128,)
# i =  97 shape =  (3, 3, 128, 128)
# i =  98 shape =  (128,)
# i =  98 shape =  (128,)
# i =  98 shape =  (128,)
# i =  98 shape =  (128,)
# i =  101 shape =  (1, 1, 128, 128)
# i =  102 shape =  (128,)
# i =  102 shape =  (128,)
# i =  102 shape =  (128,)
# i =  102 shape =  (128,)
# i =  104 shape =  (3, 3, 128, 128)
# i =  105 shape =  (128,)
# i =  105 shape =  (128,)
# i =  105 shape =  (128,)
# i =  105 shape =  (128,)
# i =  108 shape =  (1, 1, 128, 128)
# i =  109 shape =  (128,)
# i =  109 shape =  (128,)
# i =  109 shape =  (128,)
# i =  109 shape =  (128,)
# i =  111 shape =  (3, 3, 128, 128)
# i =  112 shape =  (128,)
# i =  112 shape =  (128,)
# i =  112 shape =  (128,)
# i =  112 shape =  (128,)
# i =  115 shape =  (1, 1, 128, 128)
# i =  116 shape =  (128,)
# i =  116 shape =  (128,)
# i =  116 shape =  (128,)
# i =  116 shape =  (128,)
# i =  118 shape =  (3, 3, 128, 128)
# i =  119 shape =  (128,)
# i =  119 shape =  (128,)
# i =  119 shape =  (128,)
# i =  119 shape =  (128,)
# i =  122 shape =  (1, 1, 128, 128)
# i =  123 shape =  (1, 1, 256, 128)
# i =  124 shape =  (128,)
# i =  124 shape =  (128,)
# i =  124 shape =  (128,)
# i =  124 shape =  (128,)
# i =  125 shape =  (128,)
# i =  125 shape =  (128,)
# i =  125 shape =  (128,)
# i =  125 shape =  (128,)
# i =  129 shape =  (1, 1, 256, 256)
# i =  130 shape =  (256,)
# i =  130 shape =  (256,)
# i =  130 shape =  (256,)
# i =  130 shape =  (256,)
# i =  133 shape =  (3, 3, 256, 512)
# i =  134 shape =  (512,)
# i =  134 shape =  (512,)
# i =  134 shape =  (512,)
# i =  134 shape =  (512,)
# i =  136 shape =  (1, 1, 512, 256)
# i =  137 shape =  (256,)
# i =  137 shape =  (256,)
# i =  137 shape =  (256,)
# i =  137 shape =  (256,)
# i =  139 shape =  (1, 1, 256, 256)
# i =  140 shape =  (256,)
# i =  140 shape =  (256,)
# i =  140 shape =  (256,)
# i =  140 shape =  (256,)
# i =  142 shape =  (3, 3, 256, 256)
# i =  143 shape =  (256,)
# i =  143 shape =  (256,)
# i =  143 shape =  (256,)
# i =  143 shape =  (256,)
# i =  146 shape =  (1, 1, 256, 256)
# i =  147 shape =  (256,)
# i =  147 shape =  (256,)
# i =  147 shape =  (256,)
# i =  147 shape =  (256,)
# i =  149 shape =  (3, 3, 256, 256)
# i =  150 shape =  (256,)
# i =  150 shape =  (256,)
# i =  150 shape =  (256,)
# i =  150 shape =  (256,)
# i =  153 shape =  (1, 1, 256, 256)
# i =  154 shape =  (256,)
# i =  154 shape =  (256,)
# i =  154 shape =  (256,)
# i =  154 shape =  (256,)
# i =  156 shape =  (3, 3, 256, 256)
# i =  157 shape =  (256,)
# i =  157 shape =  (256,)
# i =  157 shape =  (256,)
# i =  157 shape =  (256,)
# i =  160 shape =  (1, 1, 256, 256)
# i =  161 shape =  (256,)
# i =  161 shape =  (256,)
# i =  161 shape =  (256,)
# i =  161 shape =  (256,)
# i =  163 shape =  (3, 3, 256, 256)
# i =  164 shape =  (256,)
# i =  164 shape =  (256,)
# i =  164 shape =  (256,)
# i =  164 shape =  (256,)
# i =  167 shape =  (1, 1, 256, 256)
# i =  168 shape =  (256,)
# i =  168 shape =  (256,)
# i =  168 shape =  (256,)
# i =  168 shape =  (256,)
# i =  170 shape =  (3, 3, 256, 256)
# i =  171 shape =  (256,)
# i =  171 shape =  (256,)
# i =  171 shape =  (256,)
# i =  171 shape =  (256,)
# i =  174 shape =  (1, 1, 256, 256)
# i =  175 shape =  (256,)
# i =  175 shape =  (256,)
# i =  175 shape =  (256,)
# i =  175 shape =  (256,)
# i =  177 shape =  (3, 3, 256, 256)
# i =  178 shape =  (256,)
# i =  178 shape =  (256,)
# i =  178 shape =  (256,)
# i =  178 shape =  (256,)
# i =  181 shape =  (1, 1, 256, 256)
# i =  182 shape =  (256,)
# i =  182 shape =  (256,)
# i =  182 shape =  (256,)
# i =  182 shape =  (256,)
# i =  184 shape =  (3, 3, 256, 256)
# i =  185 shape =  (256,)
# i =  185 shape =  (256,)
# i =  185 shape =  (256,)
# i =  185 shape =  (256,)
# i =  188 shape =  (1, 1, 256, 256)
# i =  189 shape =  (256,)
# i =  189 shape =  (256,)
# i =  189 shape =  (256,)
# i =  189 shape =  (256,)
# i =  191 shape =  (3, 3, 256, 256)
# i =  192 shape =  (256,)
# i =  192 shape =  (256,)
# i =  192 shape =  (256,)
# i =  192 shape =  (256,)
# i =  195 shape =  (1, 1, 256, 256)
# i =  196 shape =  (1, 1, 512, 256)
# i =  197 shape =  (256,)
# i =  197 shape =  (256,)
# i =  197 shape =  (256,)
# i =  197 shape =  (256,)
# i =  198 shape =  (256,)
# i =  198 shape =  (256,)
# i =  198 shape =  (256,)
# i =  198 shape =  (256,)
# i =  202 shape =  (1, 1, 512, 512)
# i =  203 shape =  (512,)
# i =  203 shape =  (512,)
# i =  203 shape =  (512,)
# i =  203 shape =  (512,)
# i =  206 shape =  (3, 3, 512, 1024)
# i =  207 shape =  (1024,)
# i =  207 shape =  (1024,)
# i =  207 shape =  (1024,)
# i =  207 shape =  (1024,)
# i =  209 shape =  (1, 1, 1024, 512)
# i =  210 shape =  (512,)
# i =  210 shape =  (512,)
# i =  210 shape =  (512,)
# i =  210 shape =  (512,)
# i =  212 shape =  (1, 1, 512, 512)
# i =  213 shape =  (512,)
# i =  213 shape =  (512,)
# i =  213 shape =  (512,)
# i =  213 shape =  (512,)
# i =  215 shape =  (3, 3, 512, 512)
# i =  216 shape =  (512,)
# i =  216 shape =  (512,)
# i =  216 shape =  (512,)
# i =  216 shape =  (512,)
# i =  219 shape =  (1, 1, 512, 512)
# i =  220 shape =  (512,)
# i =  220 shape =  (512,)
# i =  220 shape =  (512,)
# i =  220 shape =  (512,)
# i =  222 shape =  (3, 3, 512, 512)
# i =  223 shape =  (512,)
# i =  223 shape =  (512,)
# i =  223 shape =  (512,)
# i =  223 shape =  (512,)
# i =  226 shape =  (1, 1, 512, 512)
# i =  227 shape =  (512,)
# i =  227 shape =  (512,)
# i =  227 shape =  (512,)
# i =  227 shape =  (512,)
# i =  229 shape =  (3, 3, 512, 512)
# i =  230 shape =  (512,)
# i =  230 shape =  (512,)
# i =  230 shape =  (512,)
# i =  230 shape =  (512,)
# i =  233 shape =  (1, 1, 512, 512)
# i =  234 shape =  (512,)
# i =  234 shape =  (512,)
# i =  234 shape =  (512,)
# i =  234 shape =  (512,)
# i =  236 shape =  (3, 3, 512, 512)
# i =  237 shape =  (512,)
# i =  237 shape =  (512,)
# i =  237 shape =  (512,)
# i =  237 shape =  (512,)
# i =  240 shape =  (1, 1, 512, 512)
# i =  241 shape =  (1, 1, 1024, 512)
# i =  242 shape =  (512,)
# i =  242 shape =  (512,)
# i =  242 shape =  (512,)
# i =  242 shape =  (512,)
# i =  243 shape =  (512,)
# i =  243 shape =  (512,)
# i =  243 shape =  (512,)
# i =  243 shape =  (512,)
# i =  247 shape =  (1, 1, 1024, 1024)
# i =  248 shape =  (1024,)
# i =  248 shape =  (1024,)
# i =  248 shape =  (1024,)
# i =  248 shape =  (1024,)
# i =  250 shape =  (1, 1, 1024, 512)
# i =  251 shape =  (512,)
# i =  251 shape =  (512,)
# i =  251 shape =  (512,)
# i =  251 shape =  (512,)
# i =  253 shape =  (3, 3, 512, 1024)
# i =  254 shape =  (1024,)
# i =  254 shape =  (1024,)
# i =  254 shape =  (1024,)
# i =  254 shape =  (1024,)
# i =  256 shape =  (1, 1, 1024, 512)
# i =  257 shape =  (512,)
# i =  257 shape =  (512,)
# i =  257 shape =  (512,)
# i =  257 shape =  (512,)
# i =  263 shape =  (1, 1, 2048, 512)
# i =  264 shape =  (512,)
# i =  264 shape =  (512,)
# i =  264 shape =  (512,)
# i =  264 shape =  (512,)
# i =  266 shape =  (3, 3, 512, 1024)
# i =  267 shape =  (1024,)
# i =  267 shape =  (1024,)
# i =  267 shape =  (1024,)
# i =  267 shape =  (1024,)
# i =  269 shape =  (1, 1, 1024, 512)
# i =  270 shape =  (512,)
# i =  270 shape =  (512,)
# i =  270 shape =  (512,)
# i =  270 shape =  (512,)
# i =  272 shape =  (1, 1, 512, 256)
# i =  273 shape =  (1, 1, 512, 256)
# i =  274 shape =  (256,)
# i =  274 shape =  (256,)
# i =  274 shape =  (256,)
# i =  274 shape =  (256,)
# i =  275 shape =  (256,)
# i =  275 shape =  (256,)
# i =  275 shape =  (256,)
# i =  275 shape =  (256,)
# i =  280 shape =  (1, 1, 512, 256)
# i =  281 shape =  (256,)
# i =  281 shape =  (256,)
# i =  281 shape =  (256,)
# i =  281 shape =  (256,)
# i =  283 shape =  (3, 3, 256, 512)
# i =  284 shape =  (512,)
# i =  284 shape =  (512,)
# i =  284 shape =  (512,)
# i =  284 shape =  (512,)
# i =  286 shape =  (1, 1, 512, 256)
# i =  287 shape =  (256,)
# i =  287 shape =  (256,)
# i =  287 shape =  (256,)
# i =  287 shape =  (256,)
# i =  289 shape =  (3, 3, 256, 512)
# i =  290 shape =  (512,)
# i =  290 shape =  (512,)
# i =  290 shape =  (512,)
# i =  290 shape =  (512,)
# i =  292 shape =  (1, 1, 512, 256)
# i =  293 shape =  (256,)
# i =  293 shape =  (256,)
# i =  293 shape =  (256,)
# i =  293 shape =  (256,)
# i =  295 shape =  (1, 1, 256, 128)
# i =  296 shape =  (1, 1, 256, 128)
# i =  297 shape =  (128,)
# i =  297 shape =  (128,)
# i =  297 shape =  (128,)
# i =  297 shape =  (128,)
# i =  298 shape =  (128,)
# i =  298 shape =  (128,)
# i =  298 shape =  (128,)
# i =  298 shape =  (128,)
# i =  303 shape =  (1, 1, 256, 128)
# i =  304 shape =  (128,)
# i =  304 shape =  (128,)
# i =  304 shape =  (128,)
# i =  304 shape =  (128,)
# i =  306 shape =  (3, 3, 128, 256)
# i =  307 shape =  (256,)
# i =  307 shape =  (256,)
# i =  307 shape =  (256,)
# i =  307 shape =  (256,)
# i =  309 shape =  (1, 1, 256, 128)
# i =  310 shape =  (128,)
# i =  310 shape =  (128,)
# i =  310 shape =  (128,)
# i =  310 shape =  (128,)
# i =  312 shape =  (3, 3, 128, 256)
# i =  313 shape =  (256,)
# i =  313 shape =  (256,)
# i =  313 shape =  (256,)
# i =  313 shape =  (256,)
# i =  315 shape =  (1, 1, 256, 128)
# i =  316 shape =  (128,)
# i =  316 shape =  (128,)
# i =  316 shape =  (128,)
# i =  316 shape =  (128,)
# i =  319 shape =  (3, 3, 128, 256)
# i =  320 shape =  (256,)
# i =  320 shape =  (256,)
# i =  320 shape =  (256,)
# i =  320 shape =  (256,)
# i =  323 shape =  (1, 1, 512, 256)
# i =  324 shape =  (256,)
# i =  324 shape =  (256,)
# i =  324 shape =  (256,)
# i =  324 shape =  (256,)
# i =  326 shape =  (3, 3, 256, 512)
# i =  327 shape =  (512,)
# i =  327 shape =  (512,)
# i =  327 shape =  (512,)
# i =  327 shape =  (512,)
# i =  329 shape =  (1, 1, 512, 256)
# i =  330 shape =  (256,)
# i =  330 shape =  (256,)
# i =  330 shape =  (256,)
# i =  330 shape =  (256,)
# i =  332 shape =  (3, 3, 256, 512)
# i =  333 shape =  (512,)
# i =  333 shape =  (512,)
# i =  333 shape =  (512,)
# i =  333 shape =  (512,)
# i =  335 shape =  (1, 1, 512, 256)
# i =  336 shape =  (256,)
# i =  336 shape =  (256,)
# i =  336 shape =  (256,)
# i =  336 shape =  (256,)
# i =  339 shape =  (3, 3, 256, 512)
# i =  340 shape =  (512,)
# i =  340 shape =  (512,)
# i =  340 shape =  (512,)
# i =  340 shape =  (512,)
# i =  343 shape =  (1, 1, 1024, 512)
# i =  344 shape =  (512,)
# i =  344 shape =  (512,)
# i =  344 shape =  (512,)
# i =  344 shape =  (512,)
# i =  346 shape =  (3, 3, 512, 1024)
# i =  347 shape =  (1024,)
# i =  347 shape =  (1024,)
# i =  347 shape =  (1024,)
# i =  347 shape =  (1024,)
# i =  349 shape =  (1, 1, 1024, 512)
# i =  350 shape =  (512,)
# i =  350 shape =  (512,)
# i =  350 shape =  (512,)
# i =  350 shape =  (512,)
# i =  352 shape =  (3, 3, 512, 1024)
# i =  353 shape =  (1024,)
# i =  353 shape =  (1024,)
# i =  353 shape =  (1024,)
# i =  353 shape =  (1024,)
# i =  355 shape =  (1, 1, 1024, 512)
# i =  356 shape =  (512,)
# i =  356 shape =  (512,)
# i =  356 shape =  (512,)
# i =  356 shape =  (512,)
# i =  358 shape =  (3, 3, 512, 1024)
# i =  359 shape =  (3, 3, 256, 512)
# i =  360 shape =  (3, 3, 128, 256)
# i =  361 shape =  (1024,)
# i =  361 shape =  (1024,)
# i =  361 shape =  (1024,)
# i =  361 shape =  (1024,)
# i =  362 shape =  (512,)
# i =  362 shape =  (512,)
# i =  362 shape =  (512,)
# i =  362 shape =  (512,)
# i =  363 shape =  (256,)
# i =  363 shape =  (256,)
# i =  363 shape =  (256,)
# i =  363 shape =  (256,)
# i =  367 shape =  (1, 1, 1024, 255)
# i =  367 shape =  (255,)
# i =  368 shape =  (1, 1, 512, 255)
# i =  368 shape =  (255,)
# i =  369 shape =  (1, 1, 256, 255)
# i =  369 shape =  (255,)

# %%
# !cp yolo4_weight.h5 /mydrive

# %%
# %cd /content/keras-yolo4
# Out:
# /content/keras-yolo4

# %%
# !wget -c 'https://github.com/kotech1/computervision/raw/master/img/dog.jpg'
# Out:
# --2021-06-17 15:19:00--  https://github.com/kotech1/computervision/raw/master/img/dog.jpg
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/kotech1/computervision/master/img/dog.jpg [following]
# --2021-06-17 15:19:00--  https://raw.githubusercontent.com/kotech1/computervision/master/img/dog.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 163759 (160K) [image/jpeg]
# Saving to: ‘dog.jpg’
#
# dog.jpg             100%[===================>] 159.92K  --.-KB/s    in 0.01s
#
# 2021-06-17 15:19:00 (15.3 MB/s) - ‘dog.jpg’ saved [163759/163759]

# %%
# !ls
# Out:
# 2007_test.txt	    data	      raccoon_anno.py	   voc_annotation.py
# 2007_train.txt	    decode_np.py      raccoon_test.txt	   VOCdevkit
# 2007_val.txt	    dog.jpg	      raccoon_train.txt    yolo4
# 2012_train.txt	    font	      README.md		   yolo4.png
# 2012_val.txt	    kmeans.py	      test.py		   yolo4.py
# callback_eval.py    LICENSE	      train_bottleneck.py  yolo4_weight.h5
# coco_annotation.py  model_data	      train.py		   yolov4.cfg
# convert.py	    predict_video.py  train_raccoon.py	   yolov4.weights

# %%
import os
import colorsys

import numpy as np
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input

from yolo4.model import yolo_eval, yolo4_body
from yolo4.utils import letterbox_image

from PIL import Image, ImageFont, ImageDraw
from timeit import default_timer as timer
import cv2
from google.colab.patches import cv2_imshow

from decode_np import Decode


def get_class(classes_path):
    classes_path = os.path.expanduser(classes_path)
    with open(classes_path) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]
    return class_names

def get_anchors(anchors_path):
    anchors_path = os.path.expanduser(anchors_path)
    with open(anchors_path) as f:
        anchors = f.readline()
    anchors = [float(x) for x in anchors.split(',')]
    return np.array(anchors).reshape(-1, 2)

if __name__ == '__main__':
    model_path = 'yolo4_weight.h5' # default pretrained weights
    #model_path = 'logs/000/'+'ep018-loss25.846.h5' # voc 2007 neck
    #model_path = 'logs/000/'+'ep046-loss6.901.h5' # raccoon neck
    #model_path = 'ep009-loss3.856.h5' # raccoon fine tuned
    #model_path = 'logs-fine/000/'+ 'ep028-loss3.622.h5' # voc 2012 fine
    anchors_path = 'model_data/yolo4_anchors.txt'
    #classes_path = 'model_data/voc_classes.txt'
    #classes_path = 'model_data/raccoon_classes.txt'
    classes_path = 'model_data/coco_classes.txt'

    class_names = get_class(classes_path)
    anchors = get_anchors(anchors_path)

    num_anchors = len(anchors)
    num_classes = len(class_names)

    model_image_size = (608, 608)

    # conf threshold and nms_iou threshold
    conf_thresh = 0.2
    nms_thresh = 0.45

    yolo4_model = yolo4_body(Input(shape=model_image_size+(3,)), num_anchors//3, num_classes)  
    yolo4_model.summary()
    #from tensorflow.keras.utils import plot_model
    #plot_model(yolo4_model, to_file='model.png')

    model_path = os.path.expanduser(model_path)
    assert model_path.endswith('.h5'), 'Keras model or weights must be a .h5 file.'

    yolo4_model.load_weights(model_path)

    _decode = Decode(conf_thresh, nms_thresh, model_image_size, yolo4_model, class_names)

    while True:
        #img = input('Input image filename:')
        try:
            image = cv2.imread('dog.jpg')
        except:
            print('Open Error! Try again!')
            continue
        else:
            image, boxes, scores, classes = _decode.detect_image(image, True)
            cv2_imshow(image)
            #cv2.imshow('image', image)
            #cv2.imwrite('output.jpg', image)
            #cv2.waitKey(0)
            #cv2.destroyAllWindows()
        break

    #yolo4_model.close_session()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 608, 608, 3) 0
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 608, 608, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 608, 608, 32) 128         conv2d_110[0][0]
# __________________________________________________________________________________________________
# mish_72 (Mish)                  (None, 608, 608, 32) 0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 609, 609, 32) 0           mish_72[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 304, 304, 64) 18432       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 304, 304, 64) 256         conv2d_111[0][0]
# __________________________________________________________________________________________________
# mish_73 (Mish)                  (None, 304, 304, 64) 0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 304, 304, 64) 4096        mish_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 304, 304, 64) 256         conv2d_113[0][0]
# __________________________________________________________________________________________________
# mish_75 (Mish)                  (None, 304, 304, 64) 0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 304, 304, 32) 2048        mish_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 304, 304, 32) 128         conv2d_114[0][0]
# __________________________________________________________________________________________________
# mish_76 (Mish)                  (None, 304, 304, 32) 0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 304, 304, 64) 18432       mish_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 304, 304, 64) 256         conv2d_115[0][0]
# __________________________________________________________________________________________________
# mish_77 (Mish)                  (None, 304, 304, 64) 0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 304, 304, 64) 0           mish_75[0][0]
#                                                                  mish_77[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 304, 304, 64) 4096        add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 304, 304, 64) 4096        mish_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 304, 304, 64) 256         conv2d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 304, 304, 64) 256         conv2d_112[0][0]
# __________________________________________________________________________________________________
# mish_78 (Mish)                  (None, 304, 304, 64) 0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# mish_74 (Mish)                  (None, 304, 304, 64) 0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 304, 304, 128 0           mish_78[0][0]
#                                                                  mish_74[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 304, 304, 64) 8192        concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 304, 304, 64) 256         conv2d_117[0][0]
# __________________________________________________________________________________________________
# mish_79 (Mish)                  (None, 304, 304, 64) 0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 305, 305, 64) 0           mish_79[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 152, 152, 128 73728       zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 152, 152, 128 512         conv2d_118[0][0]
# __________________________________________________________________________________________________
# mish_80 (Mish)                  (None, 152, 152, 128 0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 152, 152, 64) 8192        mish_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 152, 152, 64) 256         conv2d_120[0][0]
# __________________________________________________________________________________________________
# mish_82 (Mish)                  (None, 152, 152, 64) 0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 152, 152, 64) 4096        mish_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 152, 152, 64) 256         conv2d_121[0][0]
# __________________________________________________________________________________________________
# mish_83 (Mish)                  (None, 152, 152, 64) 0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 152, 152, 64) 36864       mish_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 152, 152, 64) 256         conv2d_122[0][0]
# __________________________________________________________________________________________________
# mish_84 (Mish)                  (None, 152, 152, 64) 0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 152, 152, 64) 0           mish_82[0][0]
#                                                                  mish_84[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 152, 152, 64) 4096        add_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 152, 152, 64) 256         conv2d_123[0][0]
# __________________________________________________________________________________________________
# mish_85 (Mish)                  (None, 152, 152, 64) 0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 152, 152, 64) 36864       mish_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 152, 152, 64) 256         conv2d_124[0][0]
# __________________________________________________________________________________________________
# mish_86 (Mish)                  (None, 152, 152, 64) 0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 152, 152, 64) 0           add_24[0][0]
#                                                                  mish_86[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 152, 152, 64) 4096        add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 152, 152, 64) 8192        mish_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 152, 152, 64) 256         conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 152, 152, 64) 256         conv2d_119[0][0]
# __________________________________________________________________________________________________
# mish_87 (Mish)                  (None, 152, 152, 64) 0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# mish_81 (Mish)                  (None, 152, 152, 64) 0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 152, 152, 128 0           mish_87[0][0]
#                                                                  mish_81[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 152, 152, 128 16384       concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 152, 152, 128 512         conv2d_126[0][0]
# __________________________________________________________________________________________________
# mish_88 (Mish)                  (None, 152, 152, 128 0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 153, 153, 128 0           mish_88[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 76, 76, 256)  294912      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 76, 76, 256)  1024        conv2d_127[0][0]
# __________________________________________________________________________________________________
# mish_89 (Mish)                  (None, 76, 76, 256)  0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 76, 76, 128)  32768       mish_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 76, 76, 128)  512         conv2d_129[0][0]
# __________________________________________________________________________________________________
# mish_91 (Mish)                  (None, 76, 76, 128)  0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 76, 76, 128)  16384       mish_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 76, 76, 128)  512         conv2d_130[0][0]
# __________________________________________________________________________________________________
# mish_92 (Mish)                  (None, 76, 76, 128)  0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 76, 76, 128)  147456      mish_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 76, 76, 128)  512         conv2d_131[0][0]
# __________________________________________________________________________________________________
# mish_93 (Mish)                  (None, 76, 76, 128)  0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 76, 76, 128)  0           mish_91[0][0]
#                                                                  mish_93[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 76, 76, 128)  16384       add_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 76, 76, 128)  512         conv2d_132[0][0]
# __________________________________________________________________________________________________
# mish_94 (Mish)                  (None, 76, 76, 128)  0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 76, 76, 128)  147456      mish_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 76, 76, 128)  512         conv2d_133[0][0]
# __________________________________________________________________________________________________
# mish_95 (Mish)                  (None, 76, 76, 128)  0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 76, 76, 128)  0           add_26[0][0]
#                                                                  mish_95[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 76, 76, 128)  16384       add_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 76, 76, 128)  512         conv2d_134[0][0]
# __________________________________________________________________________________________________
# mish_96 (Mish)                  (None, 76, 76, 128)  0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 76, 76, 128)  147456      mish_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 76, 76, 128)  512         conv2d_135[0][0]
# __________________________________________________________________________________________________
# mish_97 (Mish)                  (None, 76, 76, 128)  0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 76, 76, 128)  0           add_27[0][0]
#                                                                  mish_97[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 76, 76, 128)  16384       add_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 76, 76, 128)  512         conv2d_136[0][0]
# __________________________________________________________________________________________________
# mish_98 (Mish)                  (None, 76, 76, 128)  0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 76, 76, 128)  147456      mish_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 76, 76, 128)  512         conv2d_137[0][0]
# __________________________________________________________________________________________________
# mish_99 (Mish)                  (None, 76, 76, 128)  0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 76, 76, 128)  0           add_28[0][0]
#                                                                  mish_99[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 76, 76, 128)  16384       add_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 76, 76, 128)  512         conv2d_138[0][0]
# __________________________________________________________________________________________________
# mish_100 (Mish)                 (None, 76, 76, 128)  0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 76, 76, 128)  147456      mish_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 76, 76, 128)  512         conv2d_139[0][0]
# __________________________________________________________________________________________________
# mish_101 (Mish)                 (None, 76, 76, 128)  0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 76, 76, 128)  0           add_29[0][0]
#                                                                  mish_101[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 76, 76, 128)  16384       add_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 76, 76, 128)  512         conv2d_140[0][0]
# __________________________________________________________________________________________________
# mish_102 (Mish)                 (None, 76, 76, 128)  0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 76, 76, 128)  147456      mish_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 76, 76, 128)  512         conv2d_141[0][0]
# __________________________________________________________________________________________________
# mish_103 (Mish)                 (None, 76, 76, 128)  0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 76, 76, 128)  0           add_30[0][0]
#                                                                  mish_103[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 76, 76, 128)  16384       add_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 76, 76, 128)  512         conv2d_142[0][0]
# __________________________________________________________________________________________________
# mish_104 (Mish)                 (None, 76, 76, 128)  0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 76, 76, 128)  147456      mish_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 76, 76, 128)  512         conv2d_143[0][0]
# __________________________________________________________________________________________________
# mish_105 (Mish)                 (None, 76, 76, 128)  0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 76, 76, 128)  0           add_31[0][0]
#                                                                  mish_105[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 76, 76, 128)  16384       add_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 76, 76, 128)  512         conv2d_144[0][0]
# __________________________________________________________________________________________________
# mish_106 (Mish)                 (None, 76, 76, 128)  0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 76, 76, 128)  147456      mish_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 76, 76, 128)  512         conv2d_145[0][0]
# __________________________________________________________________________________________________
# mish_107 (Mish)                 (None, 76, 76, 128)  0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 76, 76, 128)  0           add_32[0][0]
#                                                                  mish_107[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 76, 76, 128)  16384       add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 76, 76, 128)  32768       mish_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 76, 76, 128)  512         conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 76, 76, 128)  512         conv2d_128[0][0]
# __________________________________________________________________________________________________
# mish_108 (Mish)                 (None, 76, 76, 128)  0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# mish_90 (Mish)                  (None, 76, 76, 128)  0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 76, 76, 256)  0           mish_108[0][0]
#                                                                  mish_90[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 76, 76, 256)  65536       concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 76, 76, 256)  1024        conv2d_147[0][0]
# __________________________________________________________________________________________________
# mish_109 (Mish)                 (None, 76, 76, 256)  0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 77, 77, 256)  0           mish_109[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 38, 38, 512)  1179648     zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 38, 38, 512)  2048        conv2d_148[0][0]
# __________________________________________________________________________________________________
# mish_110 (Mish)                 (None, 38, 38, 512)  0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 38, 38, 256)  131072      mish_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 38, 38, 256)  1024        conv2d_150[0][0]
# __________________________________________________________________________________________________
# mish_112 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 38, 38, 256)  65536       mish_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 38, 38, 256)  1024        conv2d_151[0][0]
# __________________________________________________________________________________________________
# mish_113 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 38, 38, 256)  589824      mish_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 38, 38, 256)  1024        conv2d_152[0][0]
# __________________________________________________________________________________________________
# mish_114 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 38, 38, 256)  0           mish_112[0][0]
#                                                                  mish_114[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 38, 38, 256)  65536       add_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 38, 38, 256)  1024        conv2d_153[0][0]
# __________________________________________________________________________________________________
# mish_115 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 38, 38, 256)  589824      mish_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 38, 38, 256)  1024        conv2d_154[0][0]
# __________________________________________________________________________________________________
# mish_116 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 38, 38, 256)  0           add_34[0][0]
#                                                                  mish_116[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 38, 38, 256)  65536       add_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 38, 38, 256)  1024        conv2d_155[0][0]
# __________________________________________________________________________________________________
# mish_117 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 38, 38, 256)  589824      mish_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 38, 38, 256)  1024        conv2d_156[0][0]
# __________________________________________________________________________________________________
# mish_118 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 38, 38, 256)  0           add_35[0][0]
#                                                                  mish_118[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 38, 38, 256)  65536       add_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 38, 38, 256)  1024        conv2d_157[0][0]
# __________________________________________________________________________________________________
# mish_119 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 38, 38, 256)  589824      mish_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 38, 38, 256)  1024        conv2d_158[0][0]
# __________________________________________________________________________________________________
# mish_120 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 38, 38, 256)  0           add_36[0][0]
#                                                                  mish_120[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 38, 38, 256)  65536       add_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 38, 38, 256)  1024        conv2d_159[0][0]
# __________________________________________________________________________________________________
# mish_121 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 38, 38, 256)  589824      mish_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 38, 38, 256)  1024        conv2d_160[0][0]
# __________________________________________________________________________________________________
# mish_122 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 38, 38, 256)  0           add_37[0][0]
#                                                                  mish_122[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 38, 38, 256)  65536       add_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 38, 38, 256)  1024        conv2d_161[0][0]
# __________________________________________________________________________________________________
# mish_123 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 38, 38, 256)  589824      mish_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 38, 38, 256)  1024        conv2d_162[0][0]
# __________________________________________________________________________________________________
# mish_124 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 38, 38, 256)  0           add_38[0][0]
#                                                                  mish_124[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 38, 38, 256)  65536       add_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 38, 38, 256)  1024        conv2d_163[0][0]
# __________________________________________________________________________________________________
# mish_125 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 38, 38, 256)  589824      mish_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 38, 38, 256)  1024        conv2d_164[0][0]
# __________________________________________________________________________________________________
# mish_126 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 38, 38, 256)  0           add_39[0][0]
#                                                                  mish_126[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 38, 38, 256)  65536       add_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 38, 38, 256)  1024        conv2d_165[0][0]
# __________________________________________________________________________________________________
# mish_127 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 38, 38, 256)  589824      mish_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 38, 38, 256)  1024        conv2d_166[0][0]
# __________________________________________________________________________________________________
# mish_128 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 38, 38, 256)  0           add_40[0][0]
#                                                                  mish_128[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 38, 38, 256)  65536       add_41[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 38, 38, 256)  131072      mish_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 38, 38, 256)  1024        conv2d_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 38, 38, 256)  1024        conv2d_149[0][0]
# __________________________________________________________________________________________________
# mish_129 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# mish_111 (Mish)                 (None, 38, 38, 256)  0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 38, 38, 512)  0           mish_129[0][0]
#                                                                  mish_111[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 38, 38, 512)  262144      concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 38, 38, 512)  2048        conv2d_168[0][0]
# __________________________________________________________________________________________________
# mish_130 (Mish)                 (None, 38, 38, 512)  0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 39, 39, 512)  0           mish_130[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 19, 19, 1024) 4718592     zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 19, 19, 1024) 4096        conv2d_169[0][0]
# __________________________________________________________________________________________________
# mish_131 (Mish)                 (None, 19, 19, 1024) 0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 19, 19, 512)  524288      mish_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 19, 19, 512)  2048        conv2d_171[0][0]
# __________________________________________________________________________________________________
# mish_133 (Mish)                 (None, 19, 19, 512)  0           batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 19, 19, 512)  262144      mish_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 19, 19, 512)  2048        conv2d_172[0][0]
# __________________________________________________________________________________________________
# mish_134 (Mish)                 (None, 19, 19, 512)  0           batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 19, 19, 512)  2359296     mish_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 19, 19, 512)  2048        conv2d_173[0][0]
# __________________________________________________________________________________________________
# mish_135 (Mish)                 (None, 19, 19, 512)  0           batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 19, 19, 512)  0           mish_133[0][0]
#                                                                  mish_135[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 19, 19, 512)  262144      add_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 19, 19, 512)  2048        conv2d_174[0][0]
# __________________________________________________________________________________________________
# mish_136 (Mish)                 (None, 19, 19, 512)  0           batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 19, 19, 512)  2359296     mish_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 19, 19, 512)  2048        conv2d_175[0][0]
# __________________________________________________________________________________________________
# mish_137 (Mish)                 (None, 19, 19, 512)  0           batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 19, 19, 512)  0           add_42[0][0]
#                                                                  mish_137[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 19, 19, 512)  262144      add_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 19, 19, 512)  2048        conv2d_176[0][0]
# __________________________________________________________________________________________________
# ...
# conv2d_194 (Conv2D)             (None, 38, 38, 256)  131072      leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 38, 38, 256)  1024        conv2d_194[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 38, 38, 256)  0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 38, 38, 128)  32768       leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 76, 76, 128)  32768       mish_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 38, 38, 128)  512         conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 76, 76, 128)  512         conv2d_196[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 38, 38, 128)  0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 76, 76, 128)  0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 76, 76, 128)  0           leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 76, 76, 256)  0           leaky_re_lu_49[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 76, 76, 128)  32768       concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 76, 76, 128)  512         conv2d_197[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 76, 76, 128)  0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 76, 76, 256)  294912      leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 76, 76, 256)  1024        conv2d_198[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 76, 76, 256)  0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 76, 76, 128)  32768       leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 76, 76, 128)  512         conv2d_199[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 76, 76, 128)  0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 76, 76, 256)  294912      leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 76, 76, 256)  1024        conv2d_200[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 76, 76, 256)  0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 76, 76, 128)  32768       leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 76, 76, 128)  512         conv2d_201[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 76, 76, 128)  0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 77, 77, 128)  0           leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 38, 38, 256)  294912      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 38, 38, 256)  1024        conv2d_204[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 38, 38, 256)  0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 38, 38, 512)  0           leaky_re_lu_56[0][0]
#                                                                  leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 38, 38, 256)  131072      concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 38, 38, 256)  1024        conv2d_205[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, 38, 38, 256)  0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 38, 38, 512)  1179648     leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 38, 38, 512)  2048        conv2d_206[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, 38, 38, 512)  0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 38, 38, 256)  131072      leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 38, 38, 256)  1024        conv2d_207[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, 38, 38, 256)  0           batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 38, 38, 512)  1179648     leaky_re_lu_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 38, 38, 512)  2048        conv2d_208[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, 38, 38, 512)  0           batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 38, 38, 256)  131072      leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 38, 38, 256)  1024        conv2d_209[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, 38, 38, 256)  0           batch_normalization_205[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 39, 39, 256)  0           leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 19, 19, 512)  1179648     zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 19, 19, 512)  2048        conv2d_212[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, 19, 19, 512)  0           batch_normalization_207[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 19, 19, 1024) 0           leaky_re_lu_63[0][0]
#                                                                  leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 19, 19, 512)  524288      concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 19, 19, 512)  2048        conv2d_213[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, 19, 19, 512)  0           batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 19, 19, 1024) 4718592     leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 19, 19, 1024) 4096        conv2d_214[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, 19, 19, 1024) 0           batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 19, 19, 512)  524288      leaky_re_lu_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 19, 19, 512)  2048        conv2d_215[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, 19, 19, 512)  0           batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 19, 19, 1024) 4718592     leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 19, 19, 1024) 4096        conv2d_216[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, 19, 19, 1024) 0           batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 19, 19, 512)  524288      leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 19, 19, 512)  2048        conv2d_217[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, 19, 19, 512)  0           batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 19, 19, 1024) 4718592     leaky_re_lu_68[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 38, 38, 512)  1179648     leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 76, 76, 256)  294912      leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 19, 19, 1024) 4096        conv2d_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 38, 38, 512)  2048        conv2d_210[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 76, 76, 256)  1024        conv2d_202[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, 19, 19, 1024) 0           batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, 38, 38, 512)  0           batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 76, 76, 256)  0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 19, 19, 255)  261375      leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 38, 38, 255)  130815      leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 76, 76, 255)  65535       leaky_re_lu_55[0][0]
# ==================================================================================================
# Total params: 64,429,405
# Trainable params: 64,363,101
# Non-trainable params: 66,304
# __________________________________________________________________________________________________
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7F043ED77910>

# %%
# !ls data/VOC2012/JPEGImages/ | tail +10 | head -10
# Out:
# 2007_000123.jpg
# 2007_000129.jpg
# 2007_000170.jpg
# 2007_000175.jpg
# 2007_000187.jpg
# 2007_000241.jpg
# 2007_000243.jpg
# 2007_000250.jpg
# 2007_000256.jpg
# 2007_000272.jpg

# %%
image = cv2.imread('data/VOC2012/JPEGImages/person.jpg')
image, boxes, scores, classes = _decode.detect_image(image, True)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F03E6636D90>
